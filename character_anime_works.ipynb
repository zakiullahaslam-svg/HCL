# %%
import pandas as pd

df = pd.read_csv("datasets/character_anime_works.csv")

# %%
df.head()
# Out:
#    anime_mal_id  character_mal_id character_name        role
# 0          2928              5781          Atoli        Main
# 1          2928                33          Haseo        Main
# 2          2928                32           Ovan        Main
# 3          2928                34          Shino        Main
# 4          2928              5785           Aina  Supporting

# %%
df.shape
# Out:
# (236816, 4)

# %%
df.isnull().sum()
# Out:
# anime_mal_id        0
# character_mal_id    0
# character_name      0
# role                0
# dtype: int64

# %%
df = df.drop_duplicates()
# Out:
# (236816, 4)

# %%
df.to_csv("cleanedDatasets/character_anime_works_clean.csv", index=False)
