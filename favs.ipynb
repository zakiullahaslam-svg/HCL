# %%
import pandas as pd

df = pd.read_csv("datasets/favs.csv")

# %%
df.head()
# Out:
#     username fav_type     id
# 0  ishikawas    anime  45649
# 1  ishikawas    anime  38680
# 2  ishikawas    anime    795
# 3  ishikawas    anime  37510
# 4  ishikawas    anime    820

# %%
df = df.drop_duplicates()

# %%
df.isnull().sum()
# Out:
# username    4
# fav_type    0
# id          0
# dtype: int64

# %%
df['username'] = df['username'].fillna('unknown')

# %%
df.to_csv("cleanedDatasets/favs.csv", index=False)
