# %%
import pandas as pd

df = pd.read_csv("datasets/character_nicknames.csv")

# %%
df.head()
# Out:
#    character_mal_id              nickname
# 0            280205              Hikaruko
# 1            280129              Hinacchi
# 2            280127         Bertha Willis
# 3            280066                 Jimmy
# 4            280059  Full Body Red Square

# %%
df.shape
# Out:
# (37080, 2)

# %%
df = df.dropna(subset=['character_mal_id'])

# %%
df['nickname'] = df['nickname'].fillna('Unknown')

# %%
df = df.drop_duplicates()

# %%
df.isnull().sum()
# Out:
# character_mal_id    0
# nickname            0
# dtype: int64

# %%
df.to_csv("cleanedDatasets/character_nickname.csv", index=False)
