# %%
import pandas as pd

df = pd.read_csv("datasets/person_anime_works.csv")

# %%
df.head()
# Out:
#    person_mal_id                     position  anime_mal_id
# 0              1       Theme Song Performance          3080
# 1              1    Inserted Song Performance         15699
# 2              1  Theme Song Performance (OP)           247
# 3              1       Theme Song Performance           258
# 4              1  Theme Song Performance (ED)         34825

# %%
df.isnull().sum()
# Out:
# person_mal_id    0
# position         0
# anime_mal_id     0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df.to_csv("cleanedDatasets/person_anime_works.csv", index=False)
