# %%
import pandas as pd

df = pd.read_csv("datasets/recommendations.csv")

# %%
df.head()
# Out:
#    mal_id  recommendation_mal_id
# 0    3269                    317
# 1    3269                   6922
# 2    3269                    299
# 3    3269                   3446
# 4    3269                   5681

# %%
df.isnull().sum()
# Out:
# mal_id                   0
# recommendation_mal_id    0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df.to_csv("cleanedDatasets/recommendations.csv", index=False)
